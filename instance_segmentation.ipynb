# %%
# !pip3 install tensorflow tensorflow-gpu pixellib opencv-python
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/site-packages (2.12.0)
# Collecting tensorflow-gpu
#   Downloading tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pixellib
#   Downloading pixellib-0.7.1-py3-none-any.whl (430 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 430.3/430.3 kB 7.2 MB/s eta 0:00:0000:01
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/site-packages (4.7.0.72)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/site-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.11/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/site-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.11/site-packages (from tensorflow) (0.4.8)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/site-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.11/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/site-packages (from tensorflow) (23.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/site-packages (from tensorflow) (65.6.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/site-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/site-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/site-packages (from tensorflow) (1.53.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.11/site-packages (from tensorflow) (2.12.1)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.11/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.11/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/site-packages (from tensorflow) (0.32.0)
# Collecting python_version>"3.7"
#   Downloading python_version-0.0.2-py2.py3-none-any.whl (3.4 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/site-packages (from pixellib) (9.4.0)
# Collecting scikit-image
#   Downloading scikit_image-0.20.0-cp311-cp311-macosx_10_9_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 6.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/site-packages (from pixellib) (3.7.1)
# Collecting imgaug
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 9.1 MB/s eta 0:00:00a 0:00:01
# Collecting labelme2coco
#   Downloading labelme2coco-0.2.4-py3-none-any.whl (19 kB)
# Collecting imantics
#   Downloading imantics-0.1.12.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Collecting Cython
#   Downloading Cython-0.29.34-py2.py3-none-any.whl (988 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 988.1/988.1 kB 9.3 MB/s eta 0:00:00a 0:00:01
# Collecting pyQt5
#   Downloading PyQt5-5.15.9-cp37-abi3-macosx_10_13_x86_64.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 10.9 MB/s eta 0:00:0000:0100:01
# Collecting fvcore
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 1.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting omegaconf
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 2.8 MB/s eta 0:00:00
# Collecting cloudpickle
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting yacs
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/site-packages (from pixellib) (4.65.0)
# Collecting future
#   Downloading future-0.18.3.tar.gz (840 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 kB 7.2 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting pydot
#   Using cached pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting hydra-core
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 4.6 MB/s eta 0:00:00
# Collecting black
#   Downloading black-23.3.0-cp311-cp311-macosx_10_16_x86_64.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 9.1 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.11/site-packages (from jax>=0.3.15->tensorflow) (0.0.4)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.11/site-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.17.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.28.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.2.3)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/site-packages (from black->pixellib) (8.1.3)
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting pathspec>=0.9.0
#   Downloading pathspec-0.11.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.11/site-packages (from black->pixellib) (3.2.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/site-packages (from fvcore->pixellib) (6.0)
# Collecting portalocker
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/site-packages (from imantics->pixellib) (4.9.2)
# Collecting xmljson
#   Downloading xmljson-0.2.1-py2.py3-none-any.whl (10 kB)
# Collecting imageio
#   Downloading imageio-2.27.0-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 10.4 MB/s eta 0:00:0000:0100:01
# Collecting Shapely
#   Downloading shapely-2.0.1-cp311-cp311-macosx_10_9_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 9.4 MB/s eta 0:00:00:00:0100:01
# Collecting networkx>=2.8
#   Downloading networkx-3.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 10.0 MB/s eta 0:00:0000:0100:01
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2023.3.21-py3-none-any.whl (218 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.7/218.7 kB 5.5 MB/s eta 0:00:00
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.4.1-cp311-cp311-macosx_10_13_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 5.1 MB/s eta 0:00:0000:0100:01
# Collecting lazy_loader>=0.1
#   Downloading lazy_loader-0.2-py3-none-any.whl (8.6 kB)
# Collecting sahi>=0.8.19
#   Downloading sahi-0.11.13-py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.0/101.0 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.11/site-packages (from labelme2coco->pixellib) (4.17.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/site-packages (from matplotlib->pixellib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/site-packages (from matplotlib->pixellib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/site-packages (from matplotlib->pixellib) (4.39.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/site-packages (from matplotlib->pixellib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/site-packages (from matplotlib->pixellib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/site-packages (from matplotlib->pixellib) (2.8.2)
# Collecting PyQt5-sip<13,>=12.11
#   Downloading PyQt5_sip-12.11.1-cp311-cp311-macosx_10_9_universal2.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.7/142.7 kB 4.1 MB/s eta 0:00:00
# Collecting PyQt5-Qt5>=5.15.2
#   Downloading PyQt5_Qt5-5.15.2-py3-none-macosx_10_13_intel.whl (40.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 9.4 MB/s eta 0:00:00:00:0100:01
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.11/site-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.11/site-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (0.19.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2022.12.7)
# Collecting pybboxes==0.1.6
#   Downloading pybboxes-0.1.6-py3-none-any.whl (24 kB)
# Collecting fire
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting terminaltables
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Collecting click>=8.0.0
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)
# Building wheels for collected packages: tensorflow-gpu, future, fvcore, iopath, antlr4-python3-runtime, imantics, fire
#   Building wheel for tensorflow-gpu (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/vv/rqqqmqgx2jq27_7g0vyps4_c0000gn/T/pip-install-3yikqh4j/tensorflow-gpu_c11adf38938d4dce8a913c89231f7c06/setup.py", line 37, in <module>
#           raise Exception(TF_REMOVAL_WARNING)
#       Exception:
#
#       =========================================================
#       The "tensorflow-gpu" package has been removed!
#
#       Please install "tensorflow" instead.
#
#       Other than the name, the two packages have been identical
#       since TensorFlow 2.1, or roughly since Sep 2019. For more
#       information, see: pypi.org/project/tensorflow-gpu
#       =========================================================
#
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for tensorflow-gpu
#   Running setup.py clean for tensorflow-gpu
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.3-py3-none-any.whl size=492025 sha256=48eab1cd77145a447861a80b1e2863a957cd31461526e26f307fa405aa818562
#   Stored in directory: /Users/vibhanshugarg/Library/Caches/pip/wheels/83/31/5a/7539ed9c6ac3249781de831638629a4fe503168023e1a777e2
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61405 sha256=3ce3601f2e9c9005d3c89c8aa93dadbd4ba6d8839761e61777ed57fd6d942f48
#   Stored in directory: /Users/vibhanshugarg/Library/Caches/pip/wheels/d3/8f/8b/a4fd2dc854a9d19e6283416ef0fec944e997472282ffeb1097
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31532 sha256=f84a54d0a2c0d02525b37e4dd10ae657c05fa96f9043a203b54dff2662ee231b
#   Stored in directory: /Users/vibhanshugarg/Library/Caches/pip/wheels/43/a8/c4/46bbbe4bbbcf72193333532ffa51d295bb4970ca7e6cfe8ef6
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=52bb930993e1060e4bd5260d4af140a458729107a07f1590cada0bfed30b2b62
#   Stored in directory: /Users/vibhanshugarg/Library/Caches/pip/wheels/d9/74/ce/b8dce89b7551f3d60a96650dc1e47e0c2db17f02a876140daf
#   Building wheel for imantics (setup.py) ... done
#   Created wheel for imantics: filename=imantics-0.1.12-py3-none-any.whl size=16016 sha256=a4de13cd85ab46648b5a3bbe5f15f998967c3912061f85bff75c133761c727b9
#   Stored in directory: /Users/vibhanshugarg/Library/Caches/pip/wheels/6e/d0/59/98d375250f549412167100da91c4ab0a7efc0a966cf9eb264a
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116931 sha256=6f79520439a7a1c99984078e79013239c8ab38798011d9bc4bec22a62ab0e46c
#   Stored in directory: /Users/vibhanshugarg/Library/Caches/pip/wheels/9a/9a/bd/afea12fa537e804618c037066dd825c8688b08d50e26077d6f
# Successfully built future fvcore iopath antlr4-python3-runtime imantics fire
# Failed to build tensorflow-gpu
# Installing collected packages: xmljson, python_version, PyQt5-Qt5, dataclasses, antlr4-python3-runtime, yacs, tifffile, terminaltables, tensorflow-gpu, tabulate, Shapely, PyWavelets, PyQt5-sip, pydot, pybboxes, portalocker, pathspec, omegaconf, networkx, mypy-extensions, lazy_loader, imageio, future, fire, Cython, cloudpickle, click, scikit-image, sahi, pyQt5, iopath, imantics, hydra-core, black, labelme2coco, imgaug, fvcore, pixellib
#   Running setup.py install for tensorflow-gpu ... error
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for tensorflow-gpu did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/vv/rqqqmqgx2jq27_7g0vyps4_c0000gn/T/pip-install-3yikqh4j/tensorflow-gpu_c11adf38938d4dce8a913c89231f7c06/setup.py", line 37, in <module>
#           raise Exception(TF_REMOVAL_WARNING)
#       Exception:
#
#       =========================================================
#       The "tensorflow-gpu" package has been removed!
#
#       Please install "tensorflow" instead.
#
#       Other than the name, the two packages have been identical
#       since TensorFlow 2.1, or roughly since Sep 2019. For more
#       information, see: pypi.org/project/tensorflow-gpu
#       =========================================================
#
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> tensorflow-gpu
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
# !pip3 install pixellib
# Out:
# Collecting pixellib
#   Using cached pixellib-0.7.1-py3-none-any.whl (430 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/site-packages (from pixellib) (9.4.0)
# Collecting scikit-image
#   Using cached scikit_image-0.20.0-cp311-cp311-macosx_10_9_x86_64.whl (13.0 MB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/site-packages (from pixellib) (4.7.0.72)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/site-packages (from pixellib) (3.7.1)
# Collecting imgaug
#   Using cached imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
# Collecting labelme2coco
#   Using cached labelme2coco-0.2.4-py3-none-any.whl (19 kB)
# Collecting imantics
#   Using cached imantics-0.1.12-py3-none-any.whl
# Collecting Cython
#   Using cached Cython-0.29.34-py2.py3-none-any.whl (988 kB)
# Collecting pyQt5
#   Using cached PyQt5-5.15.9-cp37-abi3-macosx_10_13_x86_64.whl (7.0 MB)
# Collecting fvcore
#   Using cached fvcore-0.1.5.post20221221-py3-none-any.whl
# Collecting iopath
#   Using cached iopath-0.1.10-py3-none-any.whl
# Collecting omegaconf
#   Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Collecting cloudpickle
#   Using cached cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/site-packages (from pixellib) (2.2.0)
# Requirement already satisfied: yacs in /usr/local/lib/python3.11/site-packages (from pixellib) (0.1.8)
# Collecting tabulate
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/site-packages (from pixellib) (4.65.0)
# Collecting future
#   Using cached future-0.18.3-py3-none-any.whl
# Collecting pydot
#   Using cached pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.11/site-packages (from pixellib) (0.6)
# Collecting hydra-core
#   Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Collecting black
#   Using cached black-23.3.0-cp311-cp311-macosx_10_16_x86_64.whl (1.5 MB)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/site-packages (from black->pixellib) (8.1.3)
# Collecting mypy-extensions>=0.4.3
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.11/site-packages (from black->pixellib) (23.0)
# Collecting pathspec>=0.9.0
#   Using cached pathspec-0.11.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.11/site-packages (from black->pixellib) (3.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/site-packages (from fvcore->pixellib) (1.23.5)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/site-packages (from fvcore->pixellib) (6.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/site-packages (from iopath->pixellib) (4.5.0)
# Collecting portalocker
#   Using cached portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/site-packages (from hydra-core->pixellib) (4.9.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/site-packages (from imantics->pixellib) (4.9.2)
# Requirement already satisfied: xmljson in /usr/local/lib/python3.11/site-packages (from imantics->pixellib) (0.2.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/site-packages (from imgaug->pixellib) (1.16.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/site-packages (from imgaug->pixellib) (1.10.1)
# Collecting imageio
#   Using cached imageio-2.27.0-py3-none-any.whl (3.4 MB)
# Collecting Shapely
#   Using cached shapely-2.0.1-cp311-cp311-macosx_10_9_x86_64.whl (1.4 MB)
# Collecting networkx>=2.8
#   Using cached networkx-3.0-py3-none-any.whl (2.0 MB)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.11/site-packages (from scikit-image->pixellib) (2023.3.21)
# Collecting PyWavelets>=1.1.1
#   Using cached PyWavelets-1.4.1-cp311-cp311-macosx_10_13_x86_64.whl (4.3 MB)
# Collecting lazy_loader>=0.1
#   Using cached lazy_loader-0.2-py3-none-any.whl (8.6 kB)
# Collecting sahi>=0.8.19
#   Using cached sahi-0.11.13-py3-none-any.whl (100 kB)
# Requirement already satisfied: jsonschema>=2.6.0 in /usr/local/lib/python3.11/site-packages (from labelme2coco->pixellib) (4.17.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/site-packages (from matplotlib->pixellib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/site-packages (from matplotlib->pixellib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/site-packages (from matplotlib->pixellib) (4.39.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/site-packages (from matplotlib->pixellib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/site-packages (from matplotlib->pixellib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/site-packages (from matplotlib->pixellib) (2.8.2)
# Collecting PyQt5-sip<13,>=12.11
#   Using cached PyQt5_sip-12.11.1-cp311-cp311-macosx_10_9_universal2.whl (142 kB)
# Requirement already satisfied: PyQt5-Qt5>=5.15.2 in /usr/local/lib/python3.11/site-packages (from pyQt5->pixellib) (5.15.2)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.11/site-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (22.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.11/site-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (0.19.3)
# Collecting pybboxes==0.1.6
#   Using cached pybboxes-0.1.6-py3-none-any.whl (24 kB)
# Collecting fire
#   Using cached fire-0.5.0-py2.py3-none-any.whl
# Requirement already satisfied: terminaltables in /usr/local/lib/python3.11/site-packages (from sahi>=0.8.19->labelme2coco->pixellib) (3.1.10)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/site-packages (from sahi>=0.8.19->labelme2coco->pixellib) (2.28.2)
# Collecting click>=8.0.0
#   Using cached click-8.0.4-py3-none-any.whl (97 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.11/site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/site-packages (from requests->sahi>=0.8.19->labelme2coco->pixellib) (2022.12.7)
# Installing collected packages: tabulate, Shapely, PyWavelets, PyQt5-sip, pydot, pybboxes, portalocker, pathspec, omegaconf, networkx, mypy-extensions, lazy_loader, imageio, future, fire, Cython, cloudpickle, click, scikit-image, sahi, pyQt5, iopath, imantics, hydra-core, black, labelme2coco, imgaug, fvcore, pixellib
#   Attempting uninstall: click
#     Found existing installation: click 8.1.3
#     Uninstalling click-8.1.3:
#       Successfully uninstalled click-8.1.3
# Successfully installed Cython-0.29.34 PyQt5-sip-12.11.1 PyWavelets-1.4.1 Shapely-2.0.1 black-23.3.0 click-8.0.4 cloudpickle-2.2.1 fire-0.5.0 future-0.18.3 fvcore-0.1.5.post20221221 hydra-core-1.3.2 imageio-2.27.0 imantics-0.1.12 imgaug-0.4.0 iopath-0.1.10 labelme2coco-0.2.4 lazy_loader-0.2 mypy-extensions-1.0.0 networkx-3.0 omegaconf-2.3.0 pathspec-0.11.1 pixellib-0.7.1 portalocker-2.7.0 pyQt5-5.15.9 pybboxes-0.1.6 pydot-1.4.2 sahi-0.11.13 scikit-image-0.20.0 tabulate-0.9.0
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
import pixellib
from pixellib.instance import instance_segmentation
import cv2
# Out:
# 2023-04-02 23:40:19.595044: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
segmentation_model = instance_segmentation()

# %%
segmentation_model.load_model('mask_rcnn_coco.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.11/site-packages/tensorflow/python/util/deprecation.py:648: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    res = segmentation_model.segmentFrame(frame,show_bboxes=True)
    image = res[1]
    cv2.imshow('Instance Segmentation', frame)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# /usr/local/lib/python3.11/site-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2023-04-02 23:40:46.970279: W tensorflow/c/c_api.cc:300] Operation '{name:'mrcnn_class_bn2/moving_variance/Assign' id:6350 op device:{requested: '', assigned: ''} def:{{{node mrcnn_class_bn2/moving_variance/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](mrcnn_class_bn2/moving_variance, mrcnn_class_bn2/moving_variance/Initializer/ones)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2023-04-02 23:40:50.504953: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -48 } dim { size: -308 } dim { size: -309 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -19 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -19 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 7 } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 1100 num_cores: 8 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 49152 l2_cache_size: 524288 l3_cache_size: 6291456 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -19 } dim { size: 7 } dim { size: 7 } dim { size: 256 } } }
# 2023-04-02 23:40:50.505045: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -48 } dim { size: -298 } dim { size: -299 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -22 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -22 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 7 } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 1100 num_cores: 8 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 49152 l2_cache_size: 524288 l3_cache_size: 6291456 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -22 } dim { size: 7 } dim { size: 7 } dim { size: 256 } } }
# 2023-04-02 23:40:50.505097: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -48 } dim { size: -286 } dim { size: -287 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -24 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -24 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 7 } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 1100 num_cores: 8 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 49152 l2_cache_size: 524288 l3_cache_size: 6291456 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -24 } dim { size: 7 } dim { size: 7 } dim { size: 256 } } }
# 2023-04-02 23:40:50.505169: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -48 } dim { size: -272 } dim { size: -273 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -26 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -26 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 7 } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 1100 num_cores: 8 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 49152 l2_cache_size: 524288 l3_cache_size: 6291456 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -26 } dim { size: 7 } dim { size: 7 } dim { size: 256 } } }
# 2023-04-02 23:40:50.508926: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -48 } dim { size: -308 } dim { size: -309 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -34 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -34 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 14 } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 1100 num_cores: 8 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 49152 l2_cache_size: 524288 l3_cache_size: 6291456 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -34 } dim { size: 14 } dim { size: 14 } dim { size: 256 } } }
# 2023-04-02 23:40:50.509014: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -48 } dim { size: -298 } dim { size: -299 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -36 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -36 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 14 } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 1100 num_cores: 8 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 49152 l2_cache_size: 524288 l3_cache_size: 6291456 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -36 } dim { size: 14 } dim { size: 14 } dim { size: 256 } } }
# 2023-04-02 23:40:50.509075: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -48 } dim { size: -286 } dim { size: -287 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -38 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -38 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 14 } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 1100 num_cores: 8 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 49152 l2_cache_size: 524288 l3_cache_size: 6291456 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -38 } dim { size: 14 } dim { size: 14 } dim { size: 256 } } }
# 2023-04-02 23:40:50.509140: W tensorflow/core/grappler/costs/op_level_cost_estimator.cc:690] Error in PredictCost() for the op: op: "CropAndResize" attr { key: "T" value { type: DT_FLOAT } } attr { key: "extrapolation_value" value { f: 0 } } attr { key: "method" value { s: "bilinear" } } inputs { dtype: DT_FLOAT shape { dim { size: -48 } dim { size: -272 } dim { size: -273 } dim { size: 256 } } } inputs { dtype: DT_FLOAT shape { dim { size: -40 } dim { size: 4 } } } inputs { dtype: DT_INT32 shape { dim { size: -40 } } } inputs { dtype: DT_INT32 shape { dim { size: 2 } } value { dtype: DT_INT32 tensor_shape { dim { size: 2 } } int_val: 14 } } device { type: "CPU" vendor: "GenuineIntel" model: "110" frequency: 1100 num_cores: 8 environment { key: "cpu_instruction_set" value: "AVX SSE, SSE2, SSE3, SSSE3, SSE4.1, SSE4.2" } environment { key: "eigen" value: "3.4.90" } l1_cache_size: 49152 l2_cache_size: 524288 l3_cache_size: 6291456 memory_size: 268435456 } outputs { dtype: DT_FLOAT shape { dim { size: -40 } dim { size: 14 } dim { size: 14 } dim { size: 256 } } }
